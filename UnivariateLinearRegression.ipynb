# %%
## Importing Pandas and MatPlotlib Library

import pandas as pd
import matplotlib.pyplot as plt

# %%
## loading the DataSets (taken from Kaggle)

trn_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
## Dropping all NaN values from CSV .

trn_df = trn_df.dropna()
test_df = test_df.dropna()

# %%
## Plotting the training Set .
## From the graph , it is clearly visible that this straight line has a slope of ~1 with 0 intercept .

trn_axs = plt.gca()
trn_df.plot(kind='scatter',x='x',y='y',ax=trn_axs,color='green')
plt.show()

# %%
## Adding an extra column in DataFrame of all 1s .

trn_df.insert(0, 'x1', 1)

# %%
## Segragating the Input and Output .

compdf = trn_df[['x1','x']]
result = trn_df[['y']]

# %%
## Setting initial values of Theta and alpha(also known as learning rate , or aggresiveness)

theta = [0.0, 0.0]
alpha = 0.0005

# %%
## The Cost Function defined :
## theta_sr is the Pandas Series containing Theta.
## H is the hypothesis
## smatn is the summation of Calculated value of product
## m is the number of the rows

def costfunction():
    theta_sr = pd.Series(theta)
    H = (compdf.values.dot(theta_sr.transpose()))
    H = pd.DataFrame(H, columns = ['y'], index = result.index)
    H = H - result
    H['y'] = H['y']**2
    smatn = H['y'].sum()
    m = H['y'].count()
    return (smatn/(2*m))

# %%
## The Gradient Descent Algorithm function .

def gradientDescent():
    theta_sr = pd.Series(theta)
    H = (compdf.values.dot(theta_sr.transpose()))
    H = pd.DataFrame(H, columns = ['y'], index = result.index)
    H = H - result
    m = H['y'].count()
    temp0 = alpha*((H['y'].sum())/m)
    
    tmp = H['y']*compdf['x']
    temp1 = alpha*((tmp.sum())/m)
    
    theta[0] = theta[0] - temp0
    theta[1] = theta[1] - temp1

# %%
## The Regression Function , which accumulates cost of the every theta getting calculated , and applying Gradient
## Descent on every loop , for the correction of theta values .

def regression():
    run = pd.DataFrame()
    for x in range(1,1000):
        run = run.append({'Run':x, 'Cost':costfunction()},ignore_index=True)
        gradientDescent()
    return run

# %%
costgrf = regression()

# %%
## Plotting of the Regression run , from the graph it is visible that the result saturated long back .

rgrsngrf = plt.gca()
costgrf.plot(kind='line',x='Run',y='Cost',ax=rgrsngrf,color='green')
plt.show()

# %%
## Plotting the data of test set .

test_axs = plt.gca()
test_df.plot(kind='scatter',x='x',y='y',ax=test_axs,color='green')
plt.show()

# %%
## Check function , to use the calculated theta values to predict values and compare it with the result given .
## If the value difference in prediction , is of +- 3 , it is treated as acceptable , else , it outputs wrong
## results , with Predicted value and actual value .

def check():
    for x,y in test_df.itertuples(index=False):
        pred = theta[0]+(x*theta[1])
        pred = round(pred,2)
        
        y = round(y,2)
        
        if (abs(pred-y)<=3):
            print('Correct Prediction !')
        else:
            print('Incorrect Prediction {} {}'.format(pred,y))

check()
# Out:
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 21.98 25.61
# Correct Prediction !
# Incorrect Prediction 35.97 41.85
# Incorrect Prediction 14.99 9.81
# Incorrect Prediction 61.94 58.87
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 5.0 8.75
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 35.97 40.25
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 86.92 90.66
# Incorrect Prediction 68.93 77.23
# Incorrect Prediction 88.92 92.12
# Incorrect Prediction 50.95 46.91
# Correct Prediction !
# Incorrect Prediction 26.97 21.71
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 27.97 33.07
# Incorrect Prediction 46.96 51.7
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 32.97 36.35
# Incorrect Prediction 90.91 95.06
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 38.96 47.49
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 71.93 68.11
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 81.92 85.46
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 54.95 51.84
# Incorrect Prediction 12.99 17.08
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 27.97 31.32
# Incorrect Prediction 80.92 73.93
# Incorrect Prediction 68.93 74.45
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 26.97 23.44
# Incorrect Prediction 55.95 49.83
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 38.96 33.38
# Correct Prediction !
# Incorrect Prediction 99.9 105.59
# Correct Prediction !
# Incorrect Prediction 42.96 48.67
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 62.94 58.61
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 20.98 16.89
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 2.0 -1.63
# Incorrect Prediction 81.92 88.54
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 89.91 98.13
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 16.98 13.41
# Incorrect Prediction 89.91 95.16
# Incorrect Prediction 12.99 9.74
# Incorrect Prediction 0.0 -3.47
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 11.99 7.47
# Incorrect Prediction 40.96 45.45
# Correct Prediction !
# Incorrect Prediction 77.93 74.5
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 63.94 67.39
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 24.98 21.32
# Correct Prediction !
# Incorrect Prediction 29.97 26.49
# Incorrect Prediction 64.94 68.95
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 52.95 60.21
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 59.94 63.19
# Correct Prediction !
# Incorrect Prediction 2.0 -2.82
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 93.91 97.0
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 21.98 18.85
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 6.99 10.41
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 15.99 21.17
# Incorrect Prediction 48.95 52.29
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 34.97 24.39
# Correct Prediction !
# Incorrect Prediction 36.97 40.04
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 1.0 -2.76
# Incorrect Prediction 31.97 37.8
# Correct Prediction !
# Incorrect Prediction 31.97 36.06
# Incorrect Prediction 45.96 49.84
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 96.91 101.07
# Incorrect Prediction 92.91 99.44
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 53.95 59.07
# Incorrect Prediction 50.95 56.43
# Incorrect Prediction 26.97 30.49
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 76.93 80.97
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 4.0 8.66
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 56.95 53.12
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 65.94 69.45
# Correct Prediction !
# Incorrect Prediction 39.96 48.1
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 44.96 41.9
# Incorrect Prediction 58.94 62.23
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 54.95 51.8
# Incorrect Prediction 54.95 51.11
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 4.0 7.65
# Correct Prediction !
# Incorrect Prediction 99.9 103.53
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 99.9 105.45
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 36.97 40.01
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 15.99 11.22
# Incorrect Prediction 5.0 0.68
# Correct Prediction !
# Incorrect Prediction 91.91 95.4
# Incorrect Prediction 45.96 52.05
# Incorrect Prediction 53.95 59.71
# Correct Prediction !
# Incorrect Prediction 43.96 37.08
# Incorrect Prediction 30.97 24.18
# Correct Prediction !
# Incorrect Prediction 85.92 82.87
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 94.91 90.71
# Incorrect Prediction 55.95 61.09
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 77.93 81.4
# Incorrect Prediction 88.92 92.4
# Incorrect Prediction 5.99 2.58
# Incorrect Prediction 66.94 63.81
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 56.95 51.57
# Correct Prediction !
# Incorrect Prediction 75.93 79.5
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 71.93 68.2
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 71.93 78.0
# Correct Prediction !
# Incorrect Prediction 5.99 11.89
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 57.94 53.52
# Incorrect Prediction 22.98 18.31
# Correct Prediction !
# Incorrect Prediction 24.98 30.41
# Incorrect Prediction 63.94 67.68
# Incorrect Prediction 20.98 17.09
# Correct Prediction !
# Incorrect Prediction 18.98 15.0
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 1.0 5.31
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Correct Prediction !
# Incorrect Prediction 46.96 52.46
